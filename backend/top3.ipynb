# %%
import os
import logging
import re
import pandas as pd 

from binance_sdk_derivatives_trading_usds_futures.derivatives_trading_usds_futures import (
    DerivativesTradingUsdsFutures,
    ConfigurationRestAPI,
    DERIVATIVES_TRADING_USDS_FUTURES_REST_API_PROD_URL,
)
from binance_sdk_derivatives_trading_usds_futures.rest_api.models import (
    KlineCandlestickDataIntervalEnum,
    TopTraderLongShortRatioPositionsPeriodEnum
)


# Configure logging
logging.basicConfig(level=logging.INFO)

# Create configuration for the REST API
configuration_rest_api = ConfigurationRestAPI(
    api_key="66aLkztQkQFuyUQuM83oqYx9ENuZH1SFFbuTSP3ClcGYa9Vqwy5cmQan9QfK7Gzd",
    # api_key= "O0ambiAxVnDs0pDAtlwVs3uiLR7uH2kh5B12WWWmEersKD9uHipkJZ80I90enw4o",
    # api_secret="",
    api_secret="V4lTk3PUCa7jwGAxPybBFzE7fN2Ob09FZR9BbchLOiGtssRnH9cnkfL2O8C7aoQW",
    base_path=os.getenv(
        "BASE_PATH",  DERIVATIVES_TRADING_USDS_FUTURES_REST_API_PROD_URL)
)

# Initialize DerivativesTradingUsdsFutures client
client = DerivativesTradingUsdsFutures(config_rest_api=configuration_rest_api)

def ticker24hr_price_change_statistics():
    try:
        response = client.rest_api.ticker24hr_price_change_statistics()

        rate_limits = response.rate_limits
        logging.info(f"ticker24hr_price_change_statistics() rate limits: {rate_limits}")

        data = response.data()
        for t in data:
            if t[0] == "actual_instance":    
                return t[1]
        # return data
        # logging.info(f"ticker24hr_price_change_statistics() response: {data}")
    except Exception as e:
        logging.error(f"ticker24hr_price_change_statistics() error: {e}")

#
def in_exchange_trading_symbols():
    try:
        response = client.rest_api.exchange_information()

        rate_limits = response.rate_limits
        # logging.info(f"exchange_info() rate limits: {rate_limits}")

        data = response.data()
        pattern =  r"usdt$"
        usdt_symbols= [
            t.symbol for t in data.symbols
            if re.search(pattern, t.symbol, flags=re.IGNORECASE) and t.status=='TRADING'
        ]
        return usdt_symbols
        logging.info(f"exchange_info() response: {data}")
    except Exception as e:
        logging.error(f"exchange_info() error: {e}")

def sort_tickers():
    """按照涨幅降序排序"""
    tickers = ticker24hr_price_change_statistics()

    if not tickers:
        return []

    in_trading_symbols = in_exchange_trading_symbols()

    if not in_trading_symbols:
        return []


    pattern =  r"usdt$"
    
    usdt_tickers= [
        t for t in tickers
        if re.search(pattern, t.symbol, flags=re.IGNORECASE)
    ]

    in_trading_tickers = [
        t for t in usdt_tickers if t.symbol in in_trading_symbols
    ]
    
    valid_tickers = [
        t for t in  in_trading_tickers
        if t.price_change_percent and not t.symbol.endswith(("UP", "DOWN", "USDTM"))  # 排除杠杆/合约交易对
    ]
    
    sorted_tickers = sorted(
        valid_tickers,
        key=lambda x: float(x.price_change_percent),
        reverse=True
    )
    
    return sorted_tickers

def get_top3_gainers():
    tickers= sort_tickers()
    tickers_list = [vars(ticker) for ticker in tickers[:3]]

    df = pd.DataFrame(tickers_list)
    df['open_time'] = pd.to_datetime(df['open_time'], unit='ms', utc=True).dt.tz_localize(None)
    df['close_time'] = pd.to_datetime(df['close_time'], unit='ms', utc=True).dt.tz_localize(None)
    # 同时优化数值列和时间列
    numeric_columns = ['price_change', 'price_change_percent', 'last_price', 'open_price', 'volume']

    # 数值列转换为浮点数
    for col in numeric_columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')


    return df

# %%
tickers = ticker24hr_price_change_statistics()
# Out:
# INFO:root:ticker24hr_price_change_statistics() rate limits: [RateLimit(rateLimitType='REQUEST_WEIGHT', interval='MINUTE', intervalNum=1, count=66, retryAfter=None)]

# %%
tickers
# Out:
# [Ticker24hrPriceChangeStatisticsResponse2(symbol='ZRCUSDT', price_change='0.0000180', price_change_percent='0.448', weighted_avg_price='0.0040225', last_price='0.0040350', last_qty='1240', open_price='0.0040170', high_price='0.0040990', low_price='0.0039540', volume='237936767', quote_volume='957112.4739650', open_time=1767437040000, close_time=1767523445002, first_id=10393016, last_id=10421439, count=28422, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='AVAAIUSDT', price_change='0.0006100', price_change_percent='6.028', weighted_avg_price='0.0106330', last_price='0.0107300', last_qty='2235', open_price='0.0101200', high_price='0.0110600', low_price='0.0100200', volume='210169615', quote_volume='2234739.7465800', open_time=1767436980000, close_time=1767523421125, first_id=77781173, last_id=77806725, count=25551, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SQDUSDT', price_change='-0.0050400', price_change_percent='-5.944', weighted_avg_price='0.0825565', last_price='0.0797500', last_qty='19', open_price='0.0847900', high_price='0.0862500', low_price='0.0781800', volume='173414128', quote_volume='14316459.6987800', open_time=1767437040000, close_time=1767523444073, first_id=86797545, last_id=87094687, count=297127, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SYRUPUSDT', price_change='0.0014100', price_change_percent='0.394', weighted_avg_price='0.3585518', last_price='0.3594600', last_qty='28', open_price='0.3580500', high_price='0.3713600', low_price='0.3506600', volume='21933632', quote_volume='7864342.4439300', open_time=1767437040000, close_time=1767523445272, first_id=149355184, last_id=149619857, count=264672, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='NEIROUSDT', price_change='0.00001880', price_change_percent='14.768', weighted_avg_price='0.00014026', last_price='0.00014610', last_qty='112976', open_price='0.00012730', high_price='0.00014870', low_price='0.00012670', volume='345112674471', quote_volume='48406130.80022760', open_time=1767437040000, close_time=1767523444096, first_id=557021658, last_id=557295835, count=274081, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MMTUSDT', price_change='-0.0035000', price_change_percent='-1.447', weighted_avg_price='0.2398920', last_price='0.2384000', last_qty='30', open_price='0.2419000', high_price='0.2464000', low_price='0.2354000', volume='35018128', quote_volume='8400567.8906000', open_time=1767437040000, close_time=1767523443906, first_id=123110274, last_id=123195636, count=85349, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='NEIROETHUSDT', price_change='-0.0077400', price_change_percent='-47.282', weighted_avg_price='0.0121364', last_price='0.0086300', last_qty='579', open_price='0.0163700', high_price='0.0193800', low_price='0.0068600', volume='6915190481', quote_volume='83925618.8442400', open_time=1758790800000, close_time=1758877250440, first_id=195022143, last_id=196070971, count=1048730, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MEMEUSDT', price_change='0.0001140', price_change_percent='10.243', weighted_avg_price='0.0011714', last_price='0.0012270', last_qty='10138', open_price='0.0011130', high_price='0.0012660', low_price='0.0011050', volume='10322100714', quote_volume='12091707.3811950', open_time=1767437040000, close_time=1767523441379, first_id=348093545, last_id=348189712, count=96133, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='WALUSDT', price_change='0.0005000', price_change_percent='0.372', weighted_avg_price='0.1345373', last_price='0.1350000', last_qty='46', open_price='0.1345000', high_price='0.1372000', low_price='0.1325000', volume='21656623', quote_volume='2913624.1261000', open_time=1767436980000, close_time=1767523438476, first_id=51021543, last_id=51058181, count=36639, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='DRIFTUSDT', price_change='0.0087000', price_change_percent='5.219', weighted_avg_price='0.1706997', last_price='0.1754000', last_qty='171', open_price='0.1667000', high_price='0.1770000', low_price='0.1657000', volume='8562003', quote_volume='1461531.6665000', open_time=1767437100000, close_time=1767523443496, first_id=79931308, last_id=79951250, count=19943, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BRUSDT', price_change='-0.0016400', price_change_percent='-2.595', weighted_avg_price='0.0625571', last_price='0.0615500', last_qty='93', open_price='0.0631900', high_price='0.0638800', low_price='0.0605700', volume='8999602', quote_volume='562988.6975000', open_time=1767436980000, close_time=1767523431025, first_id=28537346, last_id=28553637, count=16292, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='1000XECUSDT', price_change='0.00049', price_change_percent='4.383', weighted_avg_price='0.01142', last_price='0.01167', last_qty='447', open_price='0.01118', high_price='0.01174', low_price='0.01115', volume='115365349', quote_volume='1317458.16372', open_time=1767437040000, close_time=1767523445534, first_id=168138781, last_id=168164403, count=25619, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='VANAUSDT', price_change='0.036000', price_change_percent='1.515', weighted_avg_price='2.404491', last_price='2.412000', last_qty='4.48', open_price='2.376000', high_price='2.435000', low_price='2.365000', volume='573412.69', quote_volume='1378765.414020', open_time=1767436980000, close_time=1767523432728, first_id=127966026, last_id=127993543, count=27517, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='USUSDT', price_change='0.0001700', price_change_percent='2.738', weighted_avg_price='0.0063071', last_price='0.0063800', last_qty='906', open_price='0.0062100', high_price='0.0065800', low_price='0.0060900', volume='774199511', quote_volume='4882943.0379900', open_time=1767437040000, close_time=1767523442478, first_id=6383013, last_id=6434938, count=51904, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LAUSDT', price_change='0.001000', price_change_percent='0.305', weighted_avg_price='0.330539', last_price='0.329200', last_qty='31.9', open_price='0.328200', high_price='0.335500', low_price='0.326500', volume='11447692.6', quote_volume='3783911.305050', open_time=1767437040000, close_time=1767523441217, first_id=56871137, last_id=56927003, count=55867, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ANKRUSDT', price_change='0.000227', price_change_percent='3.403', weighted_avg_price='0.006866', last_price='0.006898', last_qty='21', open_price='0.006671', high_price='0.007010', low_price='0.006632', volume='223579245', quote_volume='1535062.736041', open_time=1767437040000, close_time=1767523440560, first_id=280268842, last_id=280302463, count=33617, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='STORJUSDT', price_change='0.0008', price_change_percent='0.614', weighted_avg_price='0.1314', last_price='0.1310', last_qty='151', open_price='0.1302', high_price='0.1332', low_price='0.1296', volume='46809054', quote_volume='6150249.3879', open_time=1767436980000, close_time=1767523437418, first_id=430433353, last_id=430507018, count=73663, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ACHUSDT', price_change='0.0005940', price_change_percent='7.232', weighted_avg_price='0.0088644', last_price='0.0088080', last_qty='649', open_price='0.0082140', high_price='0.0093080', low_price='0.0081640', volume='1208409031', quote_volume='10711761.7668910', open_time=1767437040000, close_time=1767523443575, first_id=246262247, last_id=246471745, count=209497, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='CELRUSDT', price_change='0.00010', price_change_percent='2.494', weighted_avg_price='0.00408', last_price='0.00411', last_qty='2158', open_price='0.00401', high_price='0.00414', low_price='0.00399', volume='194751235', quote_volume='793831.82580', open_time=1767436980000, close_time=1767523414991, first_id=240074618, last_id=240088585, count=13951, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LINEAUSDT', price_change='0.0000890', price_change_percent='1.271', weighted_avg_price='0.0070420', last_price='0.0070920', last_qty='2959', open_price='0.0070030', high_price='0.0071880', low_price='0.0069400', volume='895409597', quote_volume='6305447.2565790', open_time=1767436980000, close_time=1767523409284, first_id=80381499, last_id=80465711, count=84193, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BSWUSDT', price_change='-0.0150100', price_change_percent='-55.164', weighted_avg_price='0.0200220', last_price='0.0122000', last_qty='2716', open_price='0.0272100', high_price='0.0272600', low_price='0.0086100', volume='3292234872', quote_volume='65917286.2996200', open_time=1757840340000, close_time=1757926797553, first_id=67330467, last_id=68118672, count=788034, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='KSMUSDT', price_change='0.196', price_change_percent='2.547', weighted_avg_price='7.790', last_price='7.891', last_qty='1.8', open_price='7.695', high_price='7.902', low_price='7.652', volume='241438.4', quote_volume='1880757.679', open_time=1767436980000, close_time=1767523427443, first_id=301198485, last_id=301256308, count=57814, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='1000BONKUSDC', price_change='0.0028750', price_change_percent='32.066', weighted_avg_price='0.0108643', last_price='0.0118410', last_qty='1394', open_price='0.0089660', high_price='0.0120720', low_price='0.0089020', volume='2289142093', quote_volume='24869849.1823060', open_time=1767437040000, close_time=1767523443744, first_id=75319796, last_id=75560443, count=240596, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='PROMPTUSDT', price_change='0.0051500', price_change_percent='9.118', weighted_avg_price='0.0622252', last_price='0.0616300', last_qty='356', open_price='0.0564800', high_price='0.0674100', low_price='0.0563700', volume='183706297', quote_volume='11431168.0887600', open_time=1767437040000, close_time=1767523440347, first_id=64509711, last_id=64681272, count=171516, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SIRENUSDT', price_change='0.0024500', price_change_percent='3.411', weighted_avg_price='0.0743083', last_price='0.0742800', last_qty='336', open_price='0.0718300', high_price='0.0759000', low_price='0.0716300', volume='8778820', quote_volume='652339.0436100', open_time=1767436980000, close_time=1767523386909, first_id=34824776, last_id=34845953, count=21178, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LEVERUSDT', price_change='-0.0000191', price_change_percent='-14.514', weighted_avg_price='0.0002050', last_price='0.0001125', last_qty='50000', open_price='0.0001316', high_price='0.0002900', low_price='0.0001070', volume='413144223538', quote_volume='84688815.4293736', open_time=1756803540000, close_time=1756889996318, first_id=192029364, last_id=193157340, count=1127010, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='GIGGLEUSDT', price_change='7.96000', price_change_percent='11.339', weighted_avg_price='72.88731', last_price='78.16000', last_qty='0.80', open_price='70.20000', high_price='78.64000', low_price='69.51000', volume='485149.33', quote_volume='35361227.73370', open_time=1767437040000, close_time=1767523444209, first_id=202845883, last_id=203213204, count=367267, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='NEARUSDC', price_change='0.0570', price_change_percent='3.421', weighted_avg_price='1.7026', last_price='1.7230', last_qty='4', open_price='1.6660', high_price='1.7330', low_price='1.6640', volume='3161642', quote_volume='5383148.2680', open_time=1767436980000, close_time=1767523409091, first_id=26637907, last_id=26657888, count=19982, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BONDUSDT', price_change='0.011000', price_change_percent='1.040', weighted_avg_price='1.070275', last_price='1.069000', last_qty='46.2', open_price='1.058000', high_price='1.130000', low_price='1.021000', volume='9640937.9', quote_volume='10318452.347100', open_time=1734253140000, close_time=1734339592897, first_id=101129053, last_id=101218639, count=89587, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ALICEUSDT', price_change='0.008', price_change_percent='4.598', weighted_avg_price='0.179', last_price='0.182', last_qty='56.9', open_price='0.174', high_price='0.184', low_price='0.173', volume='17076016.5', quote_volume='3060131.622', open_time=1767437040000, close_time=1767523441246, first_id=369727504, last_id=369746286, count=18645, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MOODENGUSDT', price_change='0.0083800', price_change_percent='11.034', weighted_avg_price='0.0811739', last_price='0.0843300', last_qty='1211', open_price='0.0759500', high_price='0.0857400', low_price='0.0752700', volume='380374332', quote_volume='30876473.9186600', open_time=1767437040000, close_time=1767523442237, first_id=427535431, last_id=427869482, count=334031, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='CARVUSDT', price_change='0.0015000', price_change_percent='1.203', weighted_avg_price='0.1263392', last_price='0.1262000', last_qty='499', open_price='0.1247000', high_price='0.1283000', low_price='0.1239000', volume='10711061', quote_volume='1353226.7998000', open_time=1767437040000, close_time=1767523444481, first_id=7337215, last_id=7355530, count=18316, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='HEMIUSDT', price_change='0.0012500', price_change_percent='6.853', weighted_avg_price='0.0191417', last_price='0.0194900', last_qty='232', open_price='0.0182400', high_price='0.0199100', low_price='0.0179200', volume='377551115', quote_volume='7226962.6980690', open_time=1767437040000, close_time=1767523445259, first_id=125437638, last_id=125539922, count=102260, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MUSDT', price_change='-0.0646000', price_change_percent='-3.908', weighted_avg_price='1.6322204', last_price='1.5886000', last_qty='7', open_price='1.6532000', high_price='1.7050000', low_price='1.5692000', volume='3504687', quote_volume='5720421.7620000', open_time=1767437040000, close_time=1767523441163, first_id=128996286, last_id=129071391, count=75084, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SAHARAUSDT', price_change='0.0008800', price_change_percent='3.245', weighted_avg_price='0.0278095', last_price='0.0280000', last_qty='358', open_price='0.0271200', high_price='0.0283600', low_price='0.0269300', volume='124221427', quote_volume='3454535.7078600', open_time=1767437040000, close_time=1767523441317, first_id=82415327, last_id=82467666, count=52335, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ARUSDT', price_change='0.172', price_change_percent='4.497', weighted_avg_price='3.919', last_price='3.997', last_qty='2.5', open_price='3.825', high_price='4.034', low_price='3.810', volume='1688012.3', quote_volume='6615902.893', open_time=1767437040000, close_time=1767523441710, first_id=420466304, last_id=420553831, count=87525, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BRETTUSDT', price_change='0.0020500', price_change_percent='12.741', weighted_avg_price='0.0172315', last_price='0.0181400', last_qty='291', open_price='0.0160900', high_price='0.0183900', low_price='0.0159800', volume='368181967', quote_volume='6344332.9158400', open_time=1767437040000, close_time=1767523440125, first_id=86367100, last_id=86435109, count=68006, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MBOXUSDT', price_change='0.0004800', price_change_percent='1.483', weighted_avg_price='0.0327114', last_price='0.0328500', last_qty='145', open_price='0.0323700', high_price='0.0332600', low_price='0.0321300', volume='21801198', quote_volume='713147.7060300', open_time=1767436980000, close_time=1767523396958, first_id=41655058, last_id=41677290, count=22229, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MOVRUSDT', price_change='0.156000', price_change_percent='6.096', weighted_avg_price='2.666023', last_price='2.715000', last_qty='7.59', open_price='2.559000', high_price='2.738000', low_price='2.537000', volume='616026.45', quote_volume='1642340.875930', open_time=1767436980000, close_time=1767523435345, first_id=111696625, last_id=111735693, count=39046, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='FILUSDT', price_change='0.030', price_change_percent='2.042', weighted_avg_price='1.487', last_price='1.499', last_qty='17.4', open_price='1.469', high_price='1.524', low_price='1.454', volume='100224562.5', quote_volume='148986988.074', open_time=1767437040000, close_time=1767523441678, first_id=926828393, last_id=927075160, count=245165, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BTCUSDC', price_change='1695.0', price_change_percent='1.888', weighted_avg_price='90831.8', last_price='91464.0', last_qty='0.002', open_price='89769.0', high_price='91763.1', low_price='89586.1', volume='13816.179', quote_volume='1254948597.3', open_time=1767437040000, close_time=1767523442835, first_id=339673961, last_id=340290126, count=612091, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BLESSUSDT', price_change='-0.0011500', price_change_percent='-7.834', weighted_avg_price='0.0138682', last_price='0.0135300', last_qty='2456', open_price='0.0146800', high_price='0.0148400', low_price='0.0130600', volume='412362667', quote_volume='5718748.1122800', open_time=1767436980000, close_time=1767523436714, first_id=149440790, last_id=149520196, count=79405, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BNBUSDC', price_change='12.670', price_change_percent='1.449', weighted_avg_price='881.717', last_price='887.310', last_qty='0.02', open_price='874.640', high_price='891.180', low_price='872.070', volume='60686.49', quote_volume='53508287.366', open_time=1767437040000, close_time=1767523441056, first_id=119984751, last_id=120156937, count=172120, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ATHUSDT', price_change='0.0008300', price_change_percent='8.574', weighted_avg_price='0.0105994', last_price='0.0105100', last_qty='161', open_price='0.0096800', high_price='0.0112700', low_price='0.0096100', volume='871856407', quote_volume='9241158.1418700', open_time=1767437040000, close_time=1767523440344, first_id=38931250, last_id=38995195, count=63946, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LUMIAUSDT', price_change='0.0036000', price_change_percent='2.924', weighted_avg_price='0.1255205', last_price='0.1267000', last_qty='0.2', open_price='0.1231000', high_price='0.1289000', low_price='0.1221000', volume='17174480.3', quote_volume='2155749.2081800', open_time=1767437040000, close_time=1767523443318, first_id=33525715, last_id=33556108, count=30391, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BROCCOLIF3BUSDT', price_change='0.0004230', price_change_percent='6.908', weighted_avg_price='0.0062822', last_price='0.0065460', last_qty='145', open_price='0.0061230', high_price='0.0069710', low_price='0.0060110', volume='143772859', quote_volume='903202.7054230', open_time=1767437040000, close_time=1767523441233, first_id=70595899, last_id=70631790, count=35888, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='JCTUSDT', price_change='-0.0001380', price_change_percent='-6.253', weighted_avg_price='0.0021204', last_price='0.0020690', last_qty='32674', open_price='0.0022070', high_price='0.0022490', low_price='0.0020230', volume='771758514', quote_volume='1636408.0212260', open_time=1767437040000, close_time=1767523444881, first_id=31598842, last_id=31632683, count=33841, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LTCUSDT', price_change='0.92', price_change_percent='1.127', weighted_avg_price='81.99', last_price='82.53', last_qty='0.804', open_price='81.61', high_price='82.80', low_price='80.71', volume='973396.789', quote_volume='79806604.66', open_time=1767437040000, close_time=1767523441693, first_id=1296997530, last_id=1297261879, count=264181, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ALLOUSDT', price_change='0.0037000', price_change_percent='3.138', weighted_avg_price='0.1212455', last_price='0.1216000', last_qty='32', open_price='0.1179000', high_price='0.1256000', low_price='0.1175000', volume='77332972', quote_volume='9376278.6195000', open_time=1767437040000, close_time=1767523440337, first_id=54180161, last_id=54258705, count=78486, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BIGTIMEUSDT', price_change='0.0007800', price_change_percent='3.768', weighted_avg_price='0.0211795', last_price='0.0214800', last_qty='768', open_price='0.0207000', high_price='0.0216700', low_price='0.0206100', volume='86502718', quote_volume='1832083.0555200', open_time=1767437040000, close_time=1767523441388, first_id=336261082, last_id=336294203, count=33120, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BROCCOLI714USDT', price_change='0.0014400', price_change_percent='8.145', weighted_avg_price='0.0184051', last_price='0.0191200', last_qty='167', open_price='0.0176800', high_price='0.0196600', low_price='0.0174200', volume='1047851412', quote_volume='19285786.9121800', open_time=1767437040000, close_time=1767523444736, first_id=55262631, last_id=55460740, count=198067, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='EPTUSDT', price_change='0.0000180', price_change_percent='0.891', weighted_avg_price='0.0020314', last_price='0.0020380', last_qty='296', open_price='0.0020200', high_price='0.0021150', low_price='0.0019720', volume='532764928', quote_volume='1082280.7427740', open_time=1767437040000, close_time=1767523440340, first_id=37006150, last_id=37036454, count=30303, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='1MBABYDOGEUSDT', price_change='0.0000464', price_change_percent='6.777', weighted_avg_price='0.0007098', last_price='0.0007311', last_qty='37991', open_price='0.0006847', high_price='0.0007421', low_price='0.0006796', volume='9220683728', quote_volume='6544885.7420356', open_time=1767437040000, close_time=1767523441104, first_id=242425375, last_id=242553733, count=128347, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BARDUSDT', price_change='0.0338000', price_change_percent='4.241', weighted_avg_price='0.8243143', last_price='0.8307000', last_qty='13', open_price='0.7969000', high_price='0.8477000', low_price='0.7957000', volume='9646878', quote_volume='7952059.3516000', open_time=1767437040000, close_time=1767523444584, first_id=93518063, last_id=93673338, count=155269, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='WUSDT', price_change='0.0014000', price_change_percent='3.821', weighted_avg_price='0.0382339', last_price='0.0380400', last_qty='501.4', open_price='0.0366400', high_price='0.0406800', low_price='0.0362300', volume='507563972.6', quote_volume='19406154.0848270', open_time=1767437040000, close_time=1767523441551, first_id=231452122, last_id=231609493, count=157361, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='STRKUSDT', price_change='0.0038000', price_change_percent='4.508', weighted_avg_price='0.0861343', last_price='0.0881000', last_qty='2272.7', open_price='0.0843000', high_price='0.0884000', low_price='0.0840000', volume='189515361.2', quote_volume='16323777.2745000', open_time=1767437040000, close_time=1767523443353, first_id=204917092, last_id=204989622, count=72315, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SUPERUSDT', price_change='0.0066000', price_change_percent='3.011', weighted_avg_price='0.2232255', last_price='0.2258000', last_qty='1', open_price='0.2192000', high_price='0.2268000', low_price='0.2179000', volume='17127281', quote_volume='3823245.3876000', open_time=1767436980000, close_time=1767523437610, first_id=170591188, last_id=170651195, count=59998, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='VVVUSDT', price_change='0.154000', price_change_percent='8.480', weighted_avg_price='1.920846', last_price='1.970000', last_qty='57.97', open_price='1.816000', high_price='2.025000', low_price='1.783000', volume='1945166.29', quote_volume='3736365.788630', open_time=1767436980000, close_time=1767523436336, first_id=64965548, last_id=65004908, count=39358, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SUIUSDT', price_change='0.070700', price_change_percent='4.305', weighted_avg_price='1.673218', last_price='1.713100', last_qty='6.0', open_price='1.642400', high_price='1.717200', low_price='1.625700', volume='160070811.4', quote_volume='267833430.618330', open_time=1767437040000, close_time=1767523443839, first_id=1360878155, last_id=1361840349, count=962028, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ATUSDT', price_change='-0.0028800', price_change_percent='-1.633', weighted_avg_price='0.1740753', last_price='0.1735300', last_qty='296', open_price='0.1764100', high_price='0.1796800', low_price='0.1694300', volume='116028997', quote_volume='20197784.8923900', open_time=1767437040000, close_time=1767523444455, first_id=65224147, last_id=65645923, count=421704, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='IRYSUSDT', price_change='0.0072580', price_change_percent='26.307', weighted_avg_price='0.0333021', last_price='0.0348480', last_qty='108', open_price='0.0275900', high_price='0.0353000', low_price='0.0273660', volume='519876259', quote_volume='17312969.0442610', open_time=1767437040000, close_time=1767523444715, first_id=29803305, last_id=30054837, count=251475, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='TURBOUSDT', price_change='0.0001805', price_change_percent='9.364', weighted_avg_price='0.0020278', last_price='0.0021080', last_qty='4748', open_price='0.0019275', high_price='0.0021561', low_price='0.0019140', volume='13107957796', quote_volume='26579947.4001806', open_time=1767437040000, close_time=1767523443345, first_id=472147546, last_id=472642622, count=495060, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='EDUUSDT', price_change='-0.0004000', price_change_percent='-0.253', weighted_avg_price='0.1573341', last_price='0.1579000', last_qty='35', open_price='0.1583000', high_price='0.1605000', low_price='0.1554000', volume='9154861', quote_volume='1440371.9639000', open_time=1767436980000, close_time=1767523422022, first_id=175642452, last_id=175668047, count=25596, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='STGUSDT', price_change='0.0051000', price_change_percent='4.462', weighted_avg_price='0.1165834', last_price='0.1194000', last_qty='139', open_price='0.1143000', high_price='0.1197000', low_price='0.1135000', volume='14679856', quote_volume='1711428.1044000', open_time=1767436980000, close_time=1767523394036, first_id=172223733, last_id=172250254, count=26518, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BNTUSDT', price_change='0.0049000', price_change_percent='1.165', weighted_avg_price='0.4232274', last_price='0.4254000', last_qty='1', open_price='0.4205000', high_price='0.4277000', low_price='0.4185000', volume='890912', quote_volume='377058.3680000', open_time=1767436980000, close_time=1767523382932, first_id=100699434, last_id=100711901, count=12466, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='IOTXUSDT', price_change='0.00016', price_change_percent='2.015', weighted_avg_price='0.00801', last_price='0.00810', last_qty='10', open_price='0.00794', high_price='0.00811', low_price='0.00790', volume='64271330', quote_volume='515096.66718', open_time=1767437100000, close_time=1767523440345, first_id=236849901, last_id=236862743, count=12843, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='UMAUSDT', price_change='0.017000', price_change_percent='2.314', weighted_avg_price='0.744036', last_price='0.751700', last_qty='8', open_price='0.734700', high_price='0.759400', low_price='0.728300', volume='2232132', quote_volume='1660786.096400', open_time=1767437040000, close_time=1767523443390, first_id=170781717, last_id=170814752, count=33036, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='QTUMUSDT', price_change='0.027', price_change_percent='1.977', weighted_avg_price='1.374', last_price='1.393', last_qty='10.6', open_price='1.366', high_price='1.398', low_price='1.353', volume='2061832.4', quote_volume='2833796.985', open_time=1767436980000, close_time=1767523396946, first_id=292053226, last_id=292085794, count=32536, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='CUDISUSDT', price_change='0.0007000', price_change_percent='2.377', weighted_avg_price='0.0312151', last_price='0.0301500', last_qty='175', open_price='0.0294500', high_price='0.0328800', low_price='0.0293700', volume='63378732', quote_volume='1978373.6006500', open_time=1767436980000, close_time=1767523439129, first_id=34437176, last_id=34476085, count=38905, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='TLMUSDT', price_change='0.0000160', price_change_percent='0.609', weighted_avg_price='0.0026413', last_price='0.0026440', last_qty='1424', open_price='0.0026280', high_price='0.0026690', low_price='0.0026020', volume='1274277114', quote_volume='3365730.6258630', open_time=1767437040000, close_time=1767523441268, first_id=101489003, last_id=101562243, count=73236, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='DOGEUSDC', price_change='0.009340', price_change_percent='6.547', weighted_avg_price='0.147652', last_price='0.152010', last_qty='145', open_price='0.142670', high_price='0.153930', low_price='0.140620', volume='757341937', quote_volume='111823248.975900', open_time=1767437040000, close_time=1767523444635, first_id=144439170, last_id=144735789, count=296491, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SWARMSUSDT', price_change='0.0009500', price_change_percent='6.520', weighted_avg_price='0.0155845', last_price='0.0155200', last_qty='309', open_price='0.0145700', high_price='0.0164300', low_price='0.0144900', volume='344913526', quote_volume='5375289.9307700', open_time=1767437040000, close_time=1767523440463, first_id=101597484, last_id=101663261, count=65777, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='OCEANUSDT', price_change='0.11260', price_change_percent='18.943', weighted_avg_price='0.64549', last_price='0.70700', last_qty='72', open_price='0.59440', high_price='0.71580', low_price='0.56460', volume='102001641', quote_volume='65841451.86510', open_time=1719219660000, close_time=1719306061566, first_id=302110756, last_id=302547493, count=436733, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LINKUSDC', price_change='0.246', price_change_percent='1.877', weighted_avg_price='13.246', last_price='13.355', last_qty='1.08', open_price='13.109', high_price='13.446', low_price='13.036', volume='767703.34', quote_volume='10168921.304', open_time=1767437040000, close_time=1767523441755, first_id=62876042, last_id=62936606, count=60563, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='NIGHTUSDT', price_change='-0.0019700', price_change_percent='-2.111', weighted_avg_price='0.0930469', last_price='0.0913500', last_qty='1727', open_price='0.0933200', high_price='0.0974800', low_price='0.0897400', volume='433862728', quote_volume='40369562.0883800', open_time=1767437040000, close_time=1767523442223, first_id=60568809, last_id=61035956, count=467127, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='PUFFERUSDT', price_change='-0.0007600', price_change_percent='-1.277', weighted_avg_price='0.0588326', last_price='0.0587600', last_qty='104', open_price='0.0595200', high_price='0.0598600', low_price='0.0577600', volume='16763837', quote_volume='986259.7460900', open_time=1767437040000, close_time=1767523440540, first_id=20312240, last_id=20332137, count=19898, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='JELLYJELLYUSDT', price_change='0.0023600', price_change_percent='3.856', weighted_avg_price='0.0629771', last_price='0.0635700', last_qty='87', open_price='0.0612100', high_price='0.0661100', low_price='0.0600200', volume='193283706', quote_volume='12172453.7903700', open_time=1767436980000, close_time=1767523439619, first_id=209834684, last_id=210048114, count=213415, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ASRUSDT', price_change='0.004000', price_change_percent='0.260', weighted_avg_price='1.541630', last_price='1.543000', last_qty='8.4', open_price='1.539000', high_price='1.561000', low_price='1.505000', volume='821069.1', quote_volume='1265785.130600', open_time=1767436980000, close_time=1767523431726, first_id=45036154, last_id=45061633, count=25479, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BSVUSDT', price_change='0.37000', price_change_percent='2.020', weighted_avg_price='18.64250', last_price='18.69000', last_qty='0.3', open_price='18.32000', high_price='18.91000', low_price='18.27000', volume='77872.5', quote_volume='1451737.95300', open_time=1767437040000, close_time=1767523440345, first_id=99867442, last_id=99883043, count=15601, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='OPUSDT', price_change='0.0116000', price_change_percent='3.831', weighted_avg_price='0.3111074', last_price='0.3144000', last_qty='20.6', open_price='0.3028000', high_price='0.3176000', low_price='0.3014000', volume='99752544.6', quote_volume='31033753.7510000', open_time=1767437040000, close_time=1767523443681, first_id=913710109, last_id=913843137, count=133002, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BIDUSDT', price_change='0.0006600', price_change_percent='2.353', weighted_avg_price='0.0287227', last_price='0.0287100', last_qty='759', open_price='0.0280500', high_price='0.0296600', low_price='0.0277500', volume='37003535', quote_volume='1062840.6716800', open_time=1767436980000, close_time=1767523382276, first_id=63011874, last_id=63033389, count=21516, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='COAIUSDT', price_change='-0.0259000', price_change_percent='-5.645', weighted_avg_price='0.4613365', last_price='0.4329000', last_qty='27', open_price='0.4588000', high_price='0.5127000', low_price='0.3934000', volume='80926588', quote_volume='37334387.9104000', open_time=1767437040000, close_time=1767523441174, first_id=306948245, last_id=307374563, count=426127, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='HEIUSDT', price_change='0.000900', price_change_percent='0.718', weighted_avg_price='0.126493', last_price='0.126300', last_qty='41.4', open_price='0.125400', high_price='0.128500', low_price='0.124700', volume='4111156.0', quote_volume='520033.259800', open_time=1767437040000, close_time=1767523440559, first_id=47151181, last_id=47173924, count=22743, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ETHUSDC', price_change='41.56', price_change_percent='1.340', weighted_avg_price='3130.56', last_price='3143.50', last_qty='0.028', open_price='3101.94', high_price='3165.00', low_price='3090.14', volume='412378.801', quote_volume='1290974892.96', open_time=1767437040000, close_time=1767523445196, first_id=510104222, last_id=511143265, count=1037067, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='AEVOUSDT', price_change='0.0010200', price_change_percent='2.534', weighted_avg_price='0.0408389', last_price='0.0412700', last_qty='251.5', open_price='0.0402500', high_price='0.0417600', low_price='0.0400000', volume='39677169.8', quote_volume='1620371.1713930', open_time=1767436980000, close_time=1767523420338, first_id=165515934, last_id=165560214, count=44280, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ENAUSDC', price_change='0.0088000', price_change_percent='3.757', weighted_avg_price='0.2384240', last_price='0.2430000', last_qty='51', open_price='0.2342000', high_price='0.2443000', low_price='0.2305000', volume='58153717', quote_volume='13865241.5749000', open_time=1767437040000, close_time=1767523441261, first_id=66763376, last_id=66812213, count=48835, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='AIOUSDT', price_change='0.0136500', price_change_percent='12.731', weighted_avg_price='0.1260943', last_price='0.1208700', last_qty='100', open_price='0.1072200', high_price='0.1324000', low_price='0.1070400', volume='163699456', quote_volume='20641569.0758800', open_time=1767437040000, close_time=1767523442822, first_id=38740824, last_id=39082692, count=341831, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='AIUSDT', price_change='0.001060', price_change_percent='2.568', weighted_avg_price='0.042147', last_price='0.042340', last_qty='254', open_price='0.041280', high_price='0.042870', low_price='0.041040', volume='24511809', quote_volume='1033097.695090', open_time=1767436980000, close_time=1767523420023, first_id=238961591, last_id=238987382, count=25792, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ATAUSDT', price_change='0.0004', price_change_percent='2.210', weighted_avg_price='0.0183', last_price='0.0185', last_qty='12', open_price='0.0181', high_price='0.0185', low_price='0.0179', volume='33134056', quote_volume='605140.0530', open_time=1767437040000, close_time=1767523440345, first_id=168737252, last_id=168747418, count=10131, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='VELVETUSDT', price_change='0.0114000', price_change_percent='7.957', weighted_avg_price='0.1516247', last_price='0.1546700', last_qty='55', open_price='0.1432700', high_price='0.1642900', low_price='0.1419400', volume='14208421', quote_volume='2154347.3925300', open_time=1767437040000, close_time=1767523445332, first_id=33571966, last_id=33628642, count=56676, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='RESOLVUSDT', price_change='0.0079900', price_change_percent='11.108', weighted_avg_price='0.0772978', last_price='0.0799200', last_qty='126', open_price='0.0719300', high_price='0.0823100', low_price='0.0713000', volume='329521829', quote_volume='25471318.7926900', open_time=1767437040000, close_time=1767523445417, first_id=176475194, last_id=176905871, count=430654, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LISTAUSDT', price_change='0.0031000', price_change_percent='1.815', weighted_avg_price='0.1709707', last_price='0.1739000', last_qty='74', open_price='0.1708000', high_price='0.1746000', low_price='0.1679000', volume='7490731', quote_volume='1280695.8963000', open_time=1767436920000, close_time=1767523368221, first_id=136875244, last_id=136897063, count=21820, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='UNIUSDC', price_change='0.1030', price_change_percent='1.774', weighted_avg_price='5.8885', last_price='5.9080', last_qty='2', open_price='5.8050', high_price='6.0150', low_price='5.7600', volume='521929', quote_volume='3073354.3170', open_time=1767437040000, close_time=1767523445243, first_id=13408614, last_id=13437441, count=28827, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='WIFUSDT', price_change='0.0458000', price_change_percent='14.330', weighted_avg_price='0.3435034', last_price='0.3654000', last_qty='4197.7', open_price='0.3196000', high_price='0.3689000', low_price='0.3176000', volume='515633453.8', quote_volume='177121833.3092800', open_time=1767437040000, close_time=1767523442834, first_id=1187338418, last_id=1188124401, count=785901, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='EGLDUSDT', price_change='0.137', price_change_percent='2.255', weighted_avg_price='6.182', last_price='6.213', last_qty='0.4', open_price='6.076', high_price='6.274', low_price='6.047', volume='598159.9', quote_volume='3697657.250', open_time=1767436980000, close_time=1767523435455, first_id=368574544, last_id=368652293, count=77731, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='DOTUSDT', price_change='0.029', price_change_percent='1.370', weighted_avg_price='2.130', last_price='2.146', last_qty='233.0', open_price='2.117', high_price='2.157', low_price='2.109', volume='28731235.8', quote_volume='61210798.384', open_time=1767437040000, close_time=1767523444434, first_id=1117415679, last_id=1117626776, count=210714, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='OGUSDT', price_change='-0.989000', price_change_percent='-14.656', weighted_avg_price='6.137564', last_price='5.759000', last_qty='4.8', open_price='6.748000', high_price='6.782000', low_price='5.500000', volume='10355772.6', quote_volume='63559212.011400', open_time=1767437040000, close_time=1767523443976, first_id=70417833, last_id=71186101, count=767944, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BEATUSDT', price_change='-0.0099000', price_change_percent='-1.246', weighted_avg_price='0.8052675', last_price='0.7846000', last_qty='126', open_price='0.7945000', high_price='0.8775000', low_price='0.7565000', volume='183272253', quote_volume='147583187.3446900', open_time=1767437040000, close_time=1767523443430, first_id=304476099, last_id=306463768, count=1987318, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SANTOSUSDT', price_change='0.0570000', price_change_percent='3.158', weighted_avg_price='1.8264408', last_price='1.8620000', last_qty='3.8', open_price='1.8050000', high_price='1.8810000', low_price='1.7850000', volume='484607.7', quote_volume='885107.2961000', open_time=1767437040000, close_time=1767523443611, first_id=38992994, last_id=39008557, count=15564, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ENJUSDT', price_change='0.00073', price_change_percent='2.447', weighted_avg_price='0.03021', last_price='0.03056', last_qty='579', open_price='0.02983', high_price='0.03084', low_price='0.02964', volume='55908793', quote_volume='1688957.15316', open_time=1767436980000, close_time=1767523437940, first_id=370462664, last_id=370493005, count=30339, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MOVEUSDT', price_change='0.0011500', price_change_percent='3.190', weighted_avg_price='0.0369183', last_price='0.0372000', last_qty='424', open_price='0.0360500', high_price='0.0374800', low_price='0.0359300', volume='101294445', quote_volume='3739616.5984100', open_time=1767437040000, close_time=1767523444937, first_id=178359434, last_id=178430968, count=71531, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='PNUTUSDC', price_change='0.0071800', price_change_percent='9.003', weighted_avg_price='0.0843623', last_price='0.0869300', last_qty='190', open_price='0.0797500', high_price='0.0888900', low_price='0.0794500', volume='45051604', quote_volume='3800655.7186600', open_time=1767437040000, close_time=1767523441675, first_id=28775645, last_id=28827078, count=51432, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SXTUSDT', price_change='0.0020100', price_change_percent='7.898', weighted_avg_price='0.0261073', last_price='0.0274600', last_qty='4318', open_price='0.0254500', high_price='0.0275300', low_price='0.0252600', volume='53371590', quote_volume='1393389.1066400', open_time=1767436980000, close_time=1767523430941, first_id=45420570, last_id=45447895, count=27326, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='VFYUSDT', price_change='-0.0003300', price_change_percent='-1.116', weighted_avg_price='0.0294365', last_price='0.0292400', last_qty='190', open_price='0.0295700', high_price='0.0299700', low_price='0.0288900', volume='15985740', quote_volume='470563.8853300', open_time=1767436980000, close_time=1767523433068, first_id=33324053, last_id=33335808, count=11756, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='OMUSDT', price_change='0.0030400', price_change_percent='4.108', weighted_avg_price='0.0763467', last_price='0.0770500', last_qty='94.4', open_price='0.0740100', high_price='0.0796700', low_price='0.0736600', volume='158343454.7', quote_volume='12089000.1794290', open_time=1767437040000, close_time=1767523443956, first_id=499028973, last_id=499178704, count=149725, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='INUSDT', price_change='0.0012600', price_change_percent='1.779', weighted_avg_price='0.0715633', last_price='0.0720900', last_qty='73', open_price='0.0708300', high_price='0.0726300', low_price='0.0701500', volume='13061096', quote_volume='934695.2569900', open_time=1767437040000, close_time=1767523430786, first_id=72198027, last_id=72221272, count=23246, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ARPAUSDT', price_change='0.00035', price_change_percent='2.730', weighted_avg_price='0.01300', last_price='0.01317', last_qty='4', open_price='0.01282', high_price='0.01319', low_price='0.01277', volume='66666296', quote_volume='866685.25452', open_time=1767437040000, close_time=1767523444729, first_id=255184960, last_id=255209782, count=24818, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='PYTHUSDT', price_change='0.0033100', price_change_percent='5.261', weighted_avg_price='0.0646663', last_price='0.0662200', last_qty='152', open_price='0.0629100', high_price='0.0667700', low_price='0.0624900', volume='110541963', quote_volume='7148336.0996900', open_time=1767437040000, close_time=1767523441715, first_id=290108858, last_id=290214280, count=105420, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ORDIUSDT', price_change='0.142000', price_change_percent='3.149', weighted_avg_price='4.610990', last_price='4.652000', last_qty='19.7', open_price='4.510000', high_price='4.690000', low_price='4.502000', volume='2489189.0', quote_volume='11477625.244000', open_time=1767437040000, close_time=1767523444175, first_id=925147064, last_id=925311928, count=164844, additional_properties={}),
# ...
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='CLANKERUSDT', price_change='1.88000', price_change_percent='5.668', weighted_avg_price='33.54327', last_price='35.05000', last_qty='0.17', open_price='33.17000', high_price='35.10000', low_price='32.09000', volume='89543.02', quote_volume='3003565.96100', open_time=1767437040000, close_time=1767523444406, first_id=10867720, last_id=10904286, count=36560, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='PHBUSDT', price_change='0.0052000', price_change_percent='1.887', weighted_avg_price='0.2807061', last_price='0.2807000', last_qty='4', open_price='0.2755000', high_price='0.2866000', low_price='0.2737000', volume='3105173', quote_volume='871640.9535000', open_time=1767436980000, close_time=1767523428729, first_id=191361605, last_id=191382427, count=20822, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='WCTUSDT', price_change='0.0006000', price_change_percent='0.729', weighted_avg_price='0.0827439', last_price='0.0828800', last_qty='244', open_price='0.0822800', high_price='0.0840400', low_price='0.0818400', volume='63202318', quote_volume='5229604.4480900', open_time=1767437040000, close_time=1767523441403, first_id=122228301, last_id=122354258, count=125957, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ZKJUSDT', price_change='0.000530', price_change_percent='1.214', weighted_avg_price='0.043304', last_price='0.044180', last_qty='346.7', open_price='0.043650', high_price='0.044700', low_price='0.041880', volume='26923552.7', quote_volume='1165891.211627', open_time=1767437040000, close_time=1767523442430, first_id=40533000, last_id=40560671, count=27669, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='USELESSUSDT', price_change='0.0028400', price_change_percent='2.792', weighted_avg_price='0.1023415', last_price='0.1045500', last_qty='96', open_price='0.1017100', high_price='0.1077300', low_price='0.0975000', volume='470600221', quote_volume='48161946.8111200', open_time=1767437040000, close_time=1767523444026, first_id=44476475, last_id=45329530, count=852972, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='TOKENUSDT', price_change='-0.0004920', price_change_percent='-11.418', weighted_avg_price='0.0039980', last_price='0.0038170', last_qty='159040', open_price='0.0043090', high_price='0.0043290', low_price='0.0037600', volume='394822472', quote_volume='1578511.3727040', open_time=1764840540000, close_time=1764926973455, first_id=141490108, last_id=141524711, count=34601, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='WIFUSDC', price_change='0.0457000', price_change_percent='14.304', weighted_avg_price='0.3438026', last_price='0.3652000', last_qty='56.9', open_price='0.3195000', high_price='0.3685000', low_price='0.3173000', volume='58317416.7', quote_volume='20049679.1350800', open_time=1767437040000, close_time=1767523442845, first_id=99185739, last_id=99295472, count=109730, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='AGLDUSDT', price_change='0.0097000', price_change_percent='3.490', weighted_avg_price='0.2850419', last_price='0.2876000', last_qty='138', open_price='0.2779000', high_price='0.2914000', low_price='0.2762000', volume='4012069', quote_volume='1143607.8174000', open_time=1767436980000, close_time=1767523431726, first_id=221731700, last_id=221753057, count=21356, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='GRASSUSDT', price_change='0.0043000', price_change_percent='1.400', weighted_avg_price='0.3084386', last_price='0.3115000', last_qty='155.0', open_price='0.3072000', high_price='0.3130000', low_price='0.3009000', volume='5923188.0', quote_volume='1826939.7067800', open_time=1767436980000, close_time=1767523394318, first_id=133627723, last_id=133656104, count=28380, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ZECUSDC', price_change='0.94', price_change_percent='0.185', weighted_avg_price='508.48', last_price='508.08', last_qty='0.026', open_price='507.14', high_price='517.98', low_price='501.10', volume='51560.569', quote_volume='26217624.63', open_time=1767437040000, close_time=1767523441234, first_id=14245435, last_id=14418026, count=172561, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ZROUSDT', price_change='0.0650000', price_change_percent='4.916', weighted_avg_price='1.3527773', last_price='1.3873000', last_qty='7.3', open_price='1.3223000', high_price='1.3930000', low_price='1.3131000', volume='5513353.9', quote_volume='7458339.9563600', open_time=1767437040000, close_time=1767523442644, first_id=282491325, last_id=282634059, count=142730, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='REDUSDT', price_change='0.0068000', price_change_percent='3.013', weighted_avg_price='0.2297322', last_price='0.2325000', last_qty='22', open_price='0.2257000', high_price='0.2341000', low_price='0.2241000', volume='3912318', quote_volume='898785.3630000', open_time=1767436980000, close_time=1767523409172, first_id=81989783, last_id=82006405, count=16623, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='RSRUSDT', price_change='0.000101', price_change_percent='3.720', weighted_avg_price='0.002771', last_price='0.002816', last_qty='2126', open_price='0.002715', high_price='0.002850', low_price='0.002699', volume='1109321396', quote_volume='3073896.945504', open_time=1767437040000, close_time=1767523440345, first_id=435459092, last_id=435514594, count=55502, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='PENGUUSDC', price_change='0.0018090', price_change_percent='16.965', weighted_avg_price='0.0115627', last_price='0.0124720', last_qty='1249', open_price='0.0106630', high_price='0.0126120', low_price='0.0105490', volume='882704455', quote_volume='10206403.6041090', open_time=1767437040000, close_time=1767523444055, first_id=20270995, last_id=20425384, count=154390, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SKYUSDT', price_change='0.0024800', price_change_percent='4.079', weighted_avg_price='0.0617580', last_price='0.0632800', last_qty='115', open_price='0.0608000', high_price='0.0636200', low_price='0.0592700', volume='57711681', quote_volume='3564160.2206000', open_time=1767436980000, close_time=1767523407421, first_id=24398166, last_id=24461282, count=63116, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BLUAIUSDT', price_change='-0.0000440', price_change_percent='-0.812', weighted_avg_price='0.0052547', last_price='0.0053780', last_qty='19268', open_price='0.0054220', high_price='0.0055240', low_price='0.0050870', volume='376491604', quote_volume='1978362.2744620', open_time=1767437040000, close_time=1767523441847, first_id=22442548, last_id=22489057, count=46506, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SUIUSDC', price_change='0.070500', price_change_percent='4.293', weighted_avg_price='1.675230', last_price='1.712600', last_qty='76.5', open_price='1.642100', high_price='1.716300', low_price='1.625100', volume='15178898.8', quote_volume='25428144.098740', open_time=1767437040000, close_time=1767523444586, first_id=122884117, last_id=122998144, count=114014, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ALCHUSDT', price_change='0.0009800', price_change_percent='0.843', weighted_avg_price='0.1154918', last_price='0.1172400', last_qty='142', open_price='0.1162600', high_price='0.1175900', low_price='0.1130200', volume='25379428', quote_volume='2931114.8827000', open_time=1767437040000, close_time=1767523441884, first_id=176981235, last_id=177035230, count=53989, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='FORMUSDT', price_change='0.015600', price_change_percent='4.309', weighted_avg_price='0.365313', last_price='0.377600', last_qty='137.8', open_price='0.362000', high_price='0.377700', low_price='0.356400', volume='11865741.4', quote_volume='4334704.819860', open_time=1767437040000, close_time=1767523442177, first_id=126445270, last_id=126511764, count=66494, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='AVAUSDT', price_change='0.0102000', price_change_percent='3.433', weighted_avg_price='0.3044669', last_price='0.3073000', last_qty='28.8', open_price='0.2971000', high_price='0.3102000', low_price='0.2955000', volume='2711933.5', quote_volume='825693.9048400', open_time=1767436980000, close_time=1767523405633, first_id=52045471, last_id=52065917, count=20447, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ETHBTC', price_change='-0.000175', price_change_percent='-0.507', weighted_avg_price='0.034431', last_price='0.034354', last_qty='0.10', open_price='0.034529', high_price='0.034587', low_price='0.034218', volume='6813.39', quote_volume='234.591465', open_time=1767437040000, close_time=1767523440388, first_id=43312227, last_id=43337209, count=24792, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ONDOUSDT', price_change='0.0206000', price_change_percent='4.951', weighted_avg_price='0.4292837', last_price='0.4367000', last_qty='129.3', open_price='0.4161000', high_price='0.4432000', low_price='0.4147000', volume='66391496.9', quote_volume='28500786.8129200', open_time=1767437040000, close_time=1767523444546, first_id=465103215, last_id=465265935, count=162708, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='BTCUSDT', price_change='1701.80', price_change_percent='1.896', weighted_avg_price='90856.56', last_price='91480.50', last_qty='0.006', open_price='89778.70', high_price='91779.70', low_price='89620.00', volume='70127.470', quote_volume='6371540379.75', open_time=1767437040000, close_time=1767523444465, first_id=7070254544, last_id=7071857182, count=1595403, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='SXPUSDT', price_change='-0.0067', price_change_percent='-9.267', weighted_avg_price='0.0686', last_price='0.0656', last_qty='8868.5', open_price='0.0723', high_price='0.0730', low_price='0.0619', volume='1670595577.6', quote_volume='114647898.4085', open_time=1764838800000, close_time=1764925204596, first_id=432474004, last_id=433036575, count=561335, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ENAUSDT', price_change='0.0087000', price_change_percent='3.712', weighted_avg_price='0.2385162', last_price='0.2431000', last_qty='68', open_price='0.2344000', high_price='0.2445000', low_price='0.2307000', volume='577987164', quote_volume='137859279.8216000', open_time=1767437040000, close_time=1767523441870, first_id=684832489, last_id=685156415, count=323416, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='HBARUSDC', price_change='0.0069500', price_change_percent='5.877', weighted_avg_price='0.1216045', last_price='0.1252100', last_qty='84', open_price='0.1182600', high_price='0.1254200', low_price='0.1178300', volume='12874277', quote_volume='1565570.6289400', open_time=1767437040000, close_time=1767523444372, first_id=15310754, last_id=15332826, count=22073, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LINKUSDT', price_change='0.244', price_change_percent='1.860', weighted_avg_price='13.248', last_price='13.363', last_qty='1.82', open_price='13.119', high_price='13.456', low_price='13.045', volume='10607714.48', quote_volume='140529318.267', open_time=1767437040000, close_time=1767523441754, first_id=1491958463, last_id=1492318165, count=359586, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='PLAYUSDT', price_change='0.0032800', price_change_percent='7.607', weighted_avg_price='0.0450796', last_price='0.0464000', last_qty='1521', open_price='0.0431200', high_price='0.0465000', low_price='0.0429900', volume='65144977', quote_volume='2936711.8336000', open_time=1767437040000, close_time=1767523443529, first_id=34929042, last_id=34994114, count=65064, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='ETHUSDT_260327', price_change='41.72', price_change_percent='1.333', weighted_avg_price='3155.65', last_price='3170.86', last_qty='0.315', open_price='3129.14', high_price='3192.74', low_price='3117.21', volume='1533.080', quote_volume='4837862.95', open_time=1767436980000, close_time=1767523392413, first_id=2106110, last_id=2115957, count=9815, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MAVUSDT', price_change='0.0005900', price_change_percent='2.180', weighted_avg_price='0.0274500', last_price='0.0276600', last_qty='1', open_price='0.0270700', high_price='0.0278400', low_price='0.0269300', volume='38251531', quote_volume='1050002.9982500', open_time=1767437040000, close_time=1767523444542, first_id=161404061, last_id=161428400, count=24337, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='MELANIAUSDT', price_change='0.011100', price_change_percent='9.158', weighted_avg_price='0.136985', last_price='0.132300', last_qty='80.72', open_price='0.121200', high_price='0.145700', low_price='0.120700', volume='284206373.38', quote_volume='38932098.462602', open_time=1767437040000, close_time=1767523441983, first_id=77734577, last_id=77988000, count=253256, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='LSKUSDT', price_change='0.008500', price_change_percent='4.289', weighted_avg_price='0.201861', last_price='0.206700', last_qty='80', open_price='0.198200', high_price='0.207700', low_price='0.197600', volume='10783479', quote_volume='2176763.571200', open_time=1767437040000, close_time=1767523443036, first_id=101407185, last_id=101439562, count=32378, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='VTHOUSDT', price_change='0.0000290', price_change_percent='3.640', weighted_avg_price='0.0008109', last_price='0.0008258', last_qty='132300', open_price='0.0007968', high_price='0.0008345', low_price='0.0007926', volume='1290681396', quote_volume='1046656.2053021', open_time=1767436980000, close_time=1767523438616, first_id=39359731, last_id=39383479, count=23749, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='1000CATUSDT', price_change='0.0002410', price_change_percent='8.128', weighted_avg_price='0.0031076', last_price='0.0032060', last_qty='1638', open_price='0.0029650', high_price='0.0032580', low_price='0.0029630', volume='1024410713', quote_volume='3183477.4515120', open_time=1767437040000, close_time=1767523444815, first_id=105990986, last_id=106058816, count=67826, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='TONUSDT', price_change='0.0396000', price_change_percent='2.185', weighted_avg_price='1.8410347', last_price='1.8517000', last_qty='3.4', open_price='1.8121000', high_price='1.8869000', low_price='1.7885000', volume='24103778.4', quote_volume='44375892.4484600', open_time=1767437040000, close_time=1767523444239, first_id=368277087, last_id=368606286, count=329121, additional_properties={}),
#  Ticker24hrPriceChangeStatisticsResponse2(symbol='GRIFFAINUSDT', price_change='0.0026600', price_change_percent='13.240', weighted_avg_price='0.0222350', last_price='0.0227500', last_qty='536', open_price='0.0200900', high_price='0.0235400', low_price='0.0199700', volume='281192733', quote_volume='6252322.2251900', open_time=1767437040000, close_time=1767523443738, first_id=130742778, last_id=130818578, count=75796, additional_properties={})]

# %%
top3 = get_top3_gainers()
# Out:
# INFO:root:ticker24hr_price_change_statistics() rate limits: [RateLimit(rateLimitType='REQUEST_WEIGHT', interval='MINUTE', intervalNum=1, count=106, retryAfter=None)]

# %%
top3
# Out:
#     symbol  price_change  price_change_percent weighted_avg_price  last_price  \
# 0  MYXUSDT        2.2980                58.369          6.0415584      6.2350
# 1    BUSDT        0.0772                55.740          0.2033720      0.2157
# 2  CVXUSDT        0.6390                36.894           2.250211      2.3710
#
#   last_qty  open_price high_price  low_price        volume       quote_volume  \
# 0        3      3.9370  7.3400000  3.9370000  1.075866e+08  649990900.6605000
# 1       42      0.1385  0.2350000  0.1372000  1.908637e+09  388163445.4725000
# 2     33.9      1.7320   2.444000   1.682000  8.680159e+07   195321853.273900
#
#             open_time              close_time   first_id    last_id    count  \
# 0 2026-01-03 00:48:00 2026-01-04 00:48:51.165  369342640  374332871  4989383
# 1 2026-01-03 00:48:00 2026-01-04 00:48:51.339   56502114   59444465  2938837
# 2 2026-01-03 00:48:00 2026-01-04 00:48:50.455   10102362   11389978  1286698
#
#   additional_properties
# 0                    {}
# 1                    {}
# 2                    {}

# %%
pd.DataFrame(top3_list)
# Out:
#          symbol price_change price_change_percent weighted_avg_price  \
# 0      HOLOUSDT    0.0244400               36.941          0.0842973
# 1     RIVERUSDT     2.669000               26.549          12.390115
# 2  1000PEPEUSDT    0.0010817               26.008          0.0048966
#
#   last_price last_qty open_price high_price  low_price        volume  \
# 0  0.0906000      311  0.0661600  0.0921600  0.0655200    1902681265
# 1  12.722000     21.2  10.053000  15.400000   9.108000   104005633.0
# 2  0.0052408    20137  0.0041591  0.0053283  0.0041441  227216625107
#
#          quote_volume      open_time     close_time    first_id     last_id  \
# 0   160390947.2282800  1767269400000  1767355849044    58051664    59408293
# 1   1288641720.541900  1767269400000  1767355851666    90601908   104588232
# 2  1112586492.5312649  1767269400000  1767355849445  2376666703  2381205899
#
#       count additional_properties
# 0   1356305                    {}
# 1  13980953                    {}
# 2   4532130                    {}

# %%
if __name__ == "__main__":
    tickers = get_top3_gainers()
    print("Top 3 Gainers:")
    for t in tickers[:3]:
        print(f"Symbol: {t.symbol}, Change: {t.price_change_percent}%, Open: {t.open_price}, Close: {t.last_price}")
    print("Low 3 Gainers:")
    for t in tickers[-3:]:
        print(f"Symbol: {t.symbol}, Change: {t.price_change_percent}%, Open: {t.open_price}, Close: {t.last_price}")
# Out:
# INFO:root:ticker24hr_price_change_statistics() rate limits: [RateLimit(rateLimitType='REQUEST_WEIGHT', interval='MINUTE', intervalNum=1, count=46, retryAfter=None)]
# Top 3 Gainers:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       3 print("Top 3 Gainers:")
#       4 for t in tickers[:3]:
# ----> 5     print(f"Symbol: {t.symbol}, Change: {t.price_change_percent}%, Open: {t.open_price}, Close: {t.last_price}")
#       6 print("Low 3 Gainers:")
#       7 for t in tickers[-3:]:
#
# AttributeError: 'str' object has no attribute 'symbol'

# %%
tickers[]
