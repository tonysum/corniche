# %%
import sqlite3
from sqlalchemy import create_engine, text

data_url = 'sqlite:///../db/crypto_data.db'

# %%
engine = create_engine(data_url)

# %%
with engine.connect() as conn:
    stmt = text(f"SELECT * FROM ")

# %%
import os

# %%
PATH = os.getcwd()

# %%
PATH = os.path.abspath(os.curdir)

# %%
PATH
# Out:
# '/Users/tony/Documents/crypto/top2/jupyter'

# %%
from ./api.py import kline_candlestick_data
# Out:
#   Cell In[19], line 1
#     from ./api.py import kline_candlestick_data
#           ^
# SyntaxError: invalid syntax
